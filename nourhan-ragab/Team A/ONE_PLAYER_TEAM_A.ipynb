# %%
# %cd ../utils
from framework_utils import *
from data_utils import *
# %run framework_utils.py
# %run data_utils.py
# Out:
# /Users/nourhr/Documents/pmsys-msc/host-pmsys/utils

# %%
df_2021 = read_file_to_dataframe('../data/team_a_2021.xlsx')
df_2020 = read_file_to_dataframe('../data/team_a_2020.xlsx')

start = 50
end = 150

player_id = '25d82d44-93bb-41c6-8557-fccf35bf659f'

df_2020 = pd.DataFrame.from_dict(df_2020['Readiness'].astype(float))
df_2021 = pd.DataFrame.from_dict(df_2021['Readiness'].astype(float))

df_2020_test = df_2020[player_id].iloc[start:end]
df_2021_test = df_2021[player_id].iloc[start:end]

df_2020_train = df_2020[player_id]
df_2021_train = df_2020[player_id]

df_two_years_test = pd.concat([df_2020_test, df_2021_test], axis=1)

df_2020.drop(df_2020.index[start:end], inplace=True)
df_2021.drop(df_2021.index[start:end], inplace=True)

df_two_years_train = pd.concat([df_2020, df_2021], axis=1)

df_two_years = pd.concat([df_2020, df_2021])
df_two_years_train = df_two_years.melt().drop('variable',axis=1).dropna()
df_two_years_train.index = df_two_years_train.index + 1

df_two_years_test = pd.concat([df_2020_test])

epoch = 4
batch_size = 5
n_splits = 1
shuffle = False
predictionWindowSize = 1

# %% [markdown]
# ### Two years

# %%
trainingWindowSize = 21

training_set = df_two_years_train
test_dataset = df_two_years_test

model_file_name = 'epoch_4_bs_5_input_21_output_1'
model_path = Path('./models/{}.pkl'.format(model_file_name))


train_and_save_model(training_set, trainingWindowSize, predictionWindowSize, batch_size,
                       epoch, n_splits, shuffle, model_file_name)

predict_readiness(trainingWindowSize, predictionWindowSize, test_set, model_path)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.636896</td>
#       <td>0.391179</td>
#       <td>0.391179</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.515533</td>
#       <td>0.370952</td>
#       <td>0.370952</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.576202</td>
#       <td>0.367104</td>
#       <td>0.367104</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.615173</td>
#       <td>0.359797</td>
#       <td>0.359797</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/qp/m0h5rmz979gffg8p0gdwfkkw0000gn/T/ipykernel_33913/3596338243.py in <module>
#      11                        epoch, n_splits, shuffle, model_file_name)
#      12
# ---> 13 predict_readiness(trainingWindowSize, predictionWindowSize, test_set, model_path)
#
# ~/Documents/pmsys-msc/host-pmsys/utils/framework_utils.py in predict_readiness(training_window, prediction_window, test_dataset, model_path)
#      37 def predict_readiness(training_window, prediction_window, test_dataset, model_path):
#      38     trained_model = get_trained_model(model_path)
# ---> 39     preds, targets, _ = test_model(training_window, prediction_window, test_dataset, trained_model)
#      40     calculated_mse = calculate_mse(preds, targets, prediction_window)
#      41     plot_mse(calculated_mse, training_window, prediction_window)
#
# ~/Documents/pmsys-msc/host-pmsys/utils/framework_utils.py in test_model(training_window, prediction_window, test_dataset, trained_model)
#      59
#      60 def test_model(training_window, prediction_window, test_dataset, trained_model):
# ---> 61     X_test, y_test = SlidingWindow(training_window, horizon=prediction_window)(test_dataset)
#      62     return trained_model.get_X_preds(X_test, y_test)
#      63
#
# /usr/local/anaconda3/lib/python3.9/site-packages/tsai/data/preparation.py in _inner(o)
#     381         else:
#     382             if isinstance(o, torch.Tensor): o = o.numpy()
# --> 383             if o.ndim < 2: o = o[:, None]
#     384             if get_x is None: X = o
#     385             else: X = o[:, _get_x]
#
# AttributeError: 'function' object has no attribute 'ndim'

# %%
trainingWindowSize = 14

training_set = df_two_years_train
test_dataset = df_two_years_test

model_file_name = 'epoch_30_bs_5_input_21_output_1'
model_path = Path('./models/{}.pkl'.format(model_file_name))


train_and_save_model(training_set, trainingWindowSize, predictionWindowSize, batch_size,
                       epoch, n_splits, shuffle, model_file_name)

predict_readiness(trainingWindowSize, predictionWindowSize, test_set, model_path)

# %%
trainingWindowSize = 7

training_set = df_two_years_train
test_dataset = df_two_years_test

model_file_name = 'epoch_30_bs_5_input_21_output_1'
model_path = Path('./models/{}.pkl'.format(model_file_name))


train_and_save_model(training_set, trainingWindowSize, predictionWindowSize, batch_size,
                       epoch, n_splits, shuffle, model_file_name)

predict_readiness(trainingWindowSize, predictionWindowSize, test_set, model_path)

# %% [markdown]
# ### One year

# %% [markdown]
# ### 2020

# %%
trainingWindowSize = 7

training_set = df_2020_train
test_dataset = df_2020_test

model_file_name = 'epoch_30_bs_5_input_21_output_1'
model_path = Path('./models/{}.pkl'.format(model_file_name))


train_and_save_model(training_set, trainingWindowSize, predictionWindowSize, batch_size,
                       epoch, n_splits, shuffle, model_file_name)

predict_readiness(trainingWindowSize, predictionWindowSize, test_set, model_path)

# %%
trainingWindowSize = 14

training_set = df_2020_train
test_dataset = df_2020_test

model_file_name = 'epoch_30_bs_5_input_21_output_1'
model_path = Path('./models/{}.pkl'.format(model_file_name))


train_and_save_model(training_set, trainingWindowSize, predictionWindowSize, batch_size,
                       epoch, n_splits, shuffle, model_file_name)

predict_readiness(trainingWindowSize, predictionWindowSize, test_set, model_path)

# %%
trainingWindowSize = 21
predictionWindowSize = 1

training_set = df_2020_train
test_dataset = df_2020_test

model_file_name = 'epoch_30_bs_5_input_21_output_1'
model_path = Path('./models/{}.pkl'.format(model_file_name))


train_and_save_model(training_set, trainingWindowSize, predictionWindowSize, batch_size,
                       epoch, n_splits, shuffle, model_file_name)

predict_readiness(trainingWindowSize, predictionWindowSize, test_set, model_path)

# %% [markdown]
# ### 2021

# %%
trainingWindowSize = 7

training_set = df_2021_train
test_dataset = df_2021_test

model_file_name = 'epoch_30_bs_5_input_21_output_1'
model_path = Path('./models/{}.pkl'.format(model_file_name))


train_and_save_model(training_set, trainingWindowSize, predictionWindowSize, batch_size,
                       epoch, n_splits, shuffle, model_file_name)

predict_readiness(trainingWindowSize, predictionWindowSize, test_set, model_path)

# %%
trainingWindowSize = 14

training_set = df_2021_train
test_dataset = df_2021_test

model_file_name = 'epoch_30_bs_5_input_21_output_1'
model_path = Path('./models/{}.pkl'.format(model_file_name))


train_and_save_model(training_set, trainingWindowSize, predictionWindowSize, batch_size,
                       epoch, n_splits, shuffle, model_file_name)

predict_readiness(trainingWindowSize, predictionWindowSize, test_set, model_path)

# %%
trainingWindowSize = 21

training_set = df_2021_train
test_dataset = df_2021_test

model_file_name = 'epoch_30_bs_5_input_21_output_1'
model_path = Path('./models/{}.pkl'.format(model_file_name))


train_and_save_model(training_set, trainingWindowSize, predictionWindowSize, batch_size,
                       epoch, n_splits, shuffle, model_file_name)

predict_readiness(trainingWindowSize, predictionWindowSize, test_set, model_path)
